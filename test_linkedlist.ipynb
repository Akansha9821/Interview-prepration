# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.ref = None

class lld:
    def __init__(self):
        self.head = None
        
    def printlinkedlist(self):
        if self.head == None:
            print("Empty Linked List")
        else:
            n = self.head
            while n != None:
                print(n.data)
                n = n.ref
                
    def insert_linked_list(self, data):
        n = Node(data)
        n.ref = self.head
        self.head = n
        
        
    def insert_from_begin(self, data):
        if self.head == None:
            return Node(data)
        else:
            self.insert_linked_list(data)
            
#   UnUnderstand          
            
    def insert_from_end(self, data):
        n= Node(data)
        if self.head ==None:
            self.head = n
        else:
            new_node = self.head
            while new_node.ref != None:
                new_node = new_node.ref
            new_node.ref = n
            
    def count_node(self):
        self.visited = 0
        h = self.head
        while True:
            if h is None:
                print("Empty list")
                break
                
            h = h.ref    
            self.visited +=1
        print(self.visited)
        
        
        
    def insert_index(self, data, x):
        n = Node(data)
        h = self.head
        c = 1
        
        if h == None:
            self.insert_linked_list(data)
            
        else:
            while c < x-1:
                h = h.ref
                c +=1
                
            n.ref = h.ref
            h.ref = n

# %%
obj = lld()
obj.insert_linked_list(10)
obj.insert_linked_list(20)
obj.insert_linked_list(30)
obj.insert_linked_list(40)
obj.insert_from_begin(100)
obj.insert_from_end(300)
obj.count_node()
obj.insert_index(289, 4)
obj.printlinkedlist()
# Out:
# Empty list
# 6
# 100
# 40
# 30
# 289
# 20
# 10
# 300
